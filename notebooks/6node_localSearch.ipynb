# %%
# project root
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

print("✅ Project root added to Python path:", project_root)
from scripts.node_localSearch import run_policy
# Out:
# ✅ Project root added to Python path: c:\Users\asus\OneDrive\EV-projects\evcs-projects

# %%
from scripts.node_localSearch import run_policy
from evcs.methods import compute_total_distance

# Choose allocation rule
method_name = "closest_only"
P, Q, D = 3, 5.0, 3.5
forbid_self = True

# Run simulation
result = run_policy(method_name, P=P, Q=Q, D=D, forbid_self=False, show=True)
calc = compute_total_distance(result["model"], result["distIJ"])
print(f"Consistency check: heuristic = {result['best_metrics']['total_distance']:.4f}, recomputed = {calc:.4f}")
# Out:
# ...
#  Running Allocation Policy: closest_only
# ...
#
# 🟡 Building initial GREEDY allocation...
# ✅ Initial solution generated.
#
# 🟡 INITIAL (Greedy) SOLUTION
# Covered demand = 15.00 (93.8%)
# Total distance = 9.191
# Value score    = 1.472
# === Applying method: closest_only ===
#
# 🔴 Starting Local Search Improvement...
#
# 🔵 Starting Local Search (policy = 'closest_only')...
# Initial total distance: 9.1907
# Iter 01: improved → 4.2426
# ✅ Final best cost after Local Search (closest_only): 4.2426
# Improvement: 4.9481
#
# 🟢 FINAL BEST SOLUTION
# Covered demand = 16.00 (100.0%)
# Total distance = 4.243
# Value score    = 3.052
# Improvement    = 4.948
# Consistency check: heuristic = 4.2426, recomputed = 4.2426
