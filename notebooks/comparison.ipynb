# %%
# === Notebook Setup Cell ===
import sys, os

# Add project root (evcs-projects/)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# Add scripts folder
scripts_path = os.path.abspath(os.path.join(project_root, "scripts"))
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

print("Python path configured. Last entries:")
print(sys.path[-2:])

# import comparison helper functions (must exist in comparisonscript.py)
from comparisonscript import run_batch_one_pass
# Out:
# Python path configured. Last entries:
# ['c:\\Users\\asus\\OneDrive\\EV-projects\\evcs-projects', 'c:\\Users\\asus\\OneDrive\\EV-projects\\evcs-projects\\scripts']

# %%
# === Two-table notebook cell (updated: includes WEIGHTED) ===

import pandas as pd
import numpy as np
from pathlib import Path

# -----------------------------
# 1) Deterministic pass (MAIN TABLE)
# -----------------------------
df_det = run_batch_one_pass(
    Ns=(20,40,60),
    seeds=(1,),
    policies=("closest_only", "closest_priority", "system_optimum", "uniform"),
    greedy_mode="deterministic",
    max_iter=30,
)

# Pretty MultiIndex header for the main deterministic table (unchanged)
df_main = df_det.copy()
df_main.columns = pd.MultiIndex.from_tuples([
    ("ID", "N"),
    ("ID", "seed"),
    ("ID", "policy"),
    ("Exact", "Score exact"),
    ("Exact", "Time (s)"),
    ("Exact", "Gap (%)"),
    ("Heuristic", "Greedy score"),
    ("Heuristic", "LS score"),
    ("Heuristic", "LS time (s)"),
    ("Heuristic", "SA score"),
    ("Heuristic", "SA time (s)"),
])

# -----------------------------
# 2) RANDOM GREEDY (comparison)
# -----------------------------
df_rand = run_batch_one_pass(
    Ns=(20,40,60),
    seeds=(1,),
    policies=("closest_only", "closest_priority", "system_optimum", "uniform"),
    greedy_mode="random",
    max_iter=30,
)

# -----------------------------
# 3) WEIGHTED GREEDY (W1) — NEW
# -----------------------------
df_wgt = run_batch_one_pass(
    Ns=(20,40,60),
    seeds=(1,),
    policies=("closest_only", "closest_priority", "system_optimum", "uniform"),
    greedy_mode="weighted",  # <-- requires the changes we made in methods.py & comparisonscript.py
    max_iter=30,
)

# -----------------------------
# 4) Build comparison table (Det vs Random vs Weighted)
# -----------------------------
det = df_det.rename(columns={
    "score_greedy": "det_greedy",
    "score_LS":     "det_LS",
    "time_LS":      "det_LS_time",
})
det = det[["N","seed","policy","score_exact","time_exact","det_greedy","det_LS","det_LS_time"]]

rnd = df_rand.rename(columns={
    "score_greedy": "random_greedy",
    "score_LS":     "random_LS",
    "time_LS":      "random_LS_time",
})
rnd = rnd[["N","seed","policy","random_greedy","random_LS","random_LS_time"]]

wgt = df_wgt.rename(columns={
    "score_greedy": "weighted_greedy",
    "score_LS":     "weighted_LS",
    "time_LS":      "weighted_LS_time",
})
wgt = wgt[["N","seed","policy","weighted_greedy","weighted_LS","weighted_LS_time"]]

# Merge into one row per (N, seed, policy)
df_compare = det.merge(rnd, on=["N","seed","policy"], how="inner").merge(
    wgt, on=["N","seed","policy"], how="inner"
)

# Optional: show how close LS is to exact and how weighted compares to det/random
# Positive is better; values are percentages of exact
df_compare["Det vs Exact (%)"]      = 100 * (df_compare["det_LS"]      / df_compare["score_exact"] - 1.0)
df_compare["Random vs Exact (%)"]   = 100 * (df_compare["random_LS"]   / df_compare["score_exact"] - 1.0)
df_compare["Weighted vs Exact (%)"] = 100 * (df_compare["weighted_LS"] / df_compare["score_exact"] - 1.0)

# Direct deltas vs deterministic (in % of exact) to highlight the "weighted effect"
df_compare["(Weighted-Det) / Exact (%)"] = 100 * (df_compare["weighted_LS"] - df_compare["det_LS"]) / df_compare["score_exact"]
df_compare["(Weighted-Rand) / Exact (%)"] = 100 * (df_compare["weighted_LS"] - df_compare["random_LS"]) / df_compare["score_exact"]

# Reorder columns for readability
df_compare = df_compare[[
    "N","seed","policy",
    "score_exact","time_exact",
    "det_greedy","det_LS","det_LS_time",
    "random_greedy","random_LS","random_LS_time",
    "weighted_greedy","weighted_LS","weighted_LS_time",
    "Det vs Exact (%)","Random vs Exact (%)","Weighted vs Exact (%)",
    "(Weighted-Det) / Exact (%)","(Weighted-Rand) / Exact (%)",
]]

# -----------------------------
# 5) Export both tables to ONE Excel (now with a 3-mode sheet)
# -----------------------------
Path("results").mkdir(exist_ok=True)
out_xlsx = "results/two_tables_summary.xlsx"

# Make flat copies ONLY for saving to Excel
df_main_flat = df_main.copy()
df_main_flat.columns = ["_".join(col) for col in df_main_flat.columns]

df_compare_flat = df_compare.copy()

with pd.ExcelWriter(out_xlsx, engine="xlsxwriter") as writer:
    df_main_flat.to_excel(writer, sheet_name="Main (deterministic)", index=False)
    df_compare_flat.to_excel(writer, sheet_name="Greedy Comparison (3 modes)", index=False)

print(f"✅ Saved two tables to {out_xlsx}")

# -----------------------------
# 6) Display pretty versions in the notebook
# -----------------------------
display(df_main)     # pretty MultiIndex header (deterministic)
display(df_compare)  # comparison across deterministic, random, weighted
# Out:
# 📌 N=20 | Policy=closest_only | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 60.000 (t=0.07s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 52.178
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=52.178
# Iter 01: open/close 10->13 → 54.017
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 16.
# ✅ Final objective (closest_only) = 54.017
#      LS score = 54.017 (t=0.62s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=54.017
# Iter 029: SA improved → 55.343 (T=0.9500)
# ✅ Final SA objective (closest_only) = 55.343
#      SA score = 55.343 (t=0.23s)
#
# 📌 N=20 | Policy=closest_priority | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 59.992 (t=0.04s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 52.170
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=52.170
# Iter 01: open/close 10->13 → 54.007
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 16.
# ✅ Final objective (closest_priority) = 54.007
#      LS score = 54.007 (t=0.71s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=54.007
# Iter 102: SA improved → 55.330 (T=0.7738)
# ✅ Final SA objective (closest_priority) = 55.330
#      SA score = 55.330 (t=0.24s)
#
# 📌 N=20 | Policy=system_optimum | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 57.472 (t=0.05s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 49.886
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=49.886
# Iter 01: open/close 10->6 → 49.905
# Iter 02: open/close 6->13 → 51.349
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 17.
# ✅ Final objective (system_optimum) = 51.349
#      LS score = 51.349 (t=0.85s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=51.349
# ✅ Final SA objective (system_optimum) = 51.349
#      SA score = 51.349 (t=0.30s)
#
# 📌 N=20 | Policy=uniform | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 17.515 (t=0.02s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 17.515
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=17.515
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (uniform) = 17.515
#      LS score = 17.515 (t=1.00s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=17.515
# ✅ Final SA objective (uniform) = 17.515
#      SA score = 17.515 (t=0.27s)
#
# 📌 N=40 | Policy=closest_only | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 110.612 (t=4.60s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 105.372
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=105.372
# Iter 01: open/close 19->12 → 105.675
# Iter 02: open/close 7->36 → 105.952
# Iter 03: open/close 36->16 → 108.180
# Iter 04: open/close 12->14 → 109.472
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 19.
# ✅ Final objective (closest_only) = 109.472
#      LS score = 109.472 (t=8.51s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=109.472
# ✅ Final SA objective (closest_only) = 109.472
#      SA score = 109.472 (t=1.00s)
#
# 📌 N=40 | Policy=closest_priority | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 112.274 (t=0.12s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 105.350
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=105.350
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (closest_priority) = 105.350
#      LS score = 105.350 (t=8.64s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=105.350
# Iter 030: SA improved → 105.787 (T=0.9500)
# Iter 076: SA improved → 109.444 (T=0.8574)
# ✅ Final SA objective (closest_priority) = 109.444
#      SA score = 109.444 (t=1.18s)
#
# 📌 N=40 | Policy=system_optimum | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 106.101 (t=0.12s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 101.181
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=101.181
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (system_optimum) = 101.181
#      LS score = 101.181 (t=8.39s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=101.181
# Iter 076: SA improved → 102.727 (T=0.8574)
# Iter 110: SA improved → 102.832 (T=0.7738)
# Iter 112: SA improved → 102.843 (T=0.7738)
# ✅ Final SA objective (system_optimum) = 102.843
#      SA score = 102.843 (t=1.15s)
#
# 📌 N=40 | Policy=uniform | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 19.322 (t=0.05s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 19.322
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=19.322
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (uniform) = 19.322
#      LS score = 19.322 (t=10.96s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=19.322
# ✅ Final SA objective (uniform) = 19.322
#      SA score = 19.322 (t=1.10s)
#
# 📌 N=60 | Policy=closest_only | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
# WARNING: Loading a feasible but suboptimal solution. Please set
# load_solution=False and check results.termination_condition and
# results.found_feasible_solution() before loading a solution.
#     ⚠️ Exact SUBOPTIMAL: 179.389 (t=120.20s, term=TerminationCondition.maxTimeLimit)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 168.521
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=168.521
# Iter 01: open/close 32->42 → 170.740
# Iter 02: open/close 42->26 → 172.882
# Iter 03: open/close 2->39 → 174.687
# Iter 04: open/close 50->6 → 175.103
# Iter 05: open/close 26->37 → 175.440
# Iter 06: open/close 41->47 → 175.741
# Iter 07: open/close 6->29 → 177.335
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 22.
# ✅ Final objective (closest_only) = 177.335
#      LS score = 177.335 (t=36.87s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=177.335
# ✅ Final SA objective (closest_only) = 177.335
#      SA score = 177.335 (t=2.04s)
#
# 📌 N=60 | Policy=closest_priority | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 179.971 (t=0.11s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 166.441
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=166.441
# Iter 01: open/close 20->53 → 166.442
# Iter 02: open/close 15->0 → 170.010
# Iter 03: open/close 23->49 → 170.012
# Iter 04: open/close 0->21 → 171.968
# Iter 05: open/close 16->14 → 172.237
# Iter 06: open/close 14->43 → 172.239
# Iter 07: open/close 49->6 → 172.239
# Iter 08: open/close 22->12 → 172.263
# Iter 09: open/close 43->14 → 173.769
# Iter 10: open/close 53->20 → 176.293
# Iter 11: open/close 6->29 → 176.855
# Iter 12: open/close 29->50 → 176.883
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 27.
# ✅ Final objective (closest_priority) = 176.883
#      LS score = 176.883 (t=45.91s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=176.883
# ✅ Final SA objective (closest_priority) = 176.883
#      SA score = 176.883 (t=2.18s)
#
# 📌 N=60 | Policy=system_optimum | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 171.815 (t=2.02s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 159.930
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=159.930
# Iter 01: open/close 16->20 → 160.543
# Iter 02: open/close 10->47 → 162.297
# Iter 03: open/close 46->16 → 164.277
# Iter 04: open/close 47->25 → 164.789
# Iter 05: open/close 22->37 → 166.478
# Iter 06: open/close 25->10 → 166.554
# Iter 07: open/close 29->6 → 166.649
# Iter 08: open/close 10->25 → 166.776
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 23.
# ✅ Final objective (system_optimum) = 166.776
#      LS score = 166.776 (t=36.10s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=166.776
# ✅ Final SA objective (system_optimum) = 166.776
#      SA score = 166.776 (t=2.20s)
#
# 📌 N=60 | Policy=uniform | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 23.984 (t=0.08s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 23.984
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=23.984
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (uniform) = 23.984
#      LS score = 23.984 (t=38.79s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=23.984
# ✅ Final SA objective (uniform) = 23.984
#      SA score = 23.984 (t=2.28s)
#
# 📌 N=20 | Policy=closest_only | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 60.000 (t=0.08s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (closest_only).
#      Greedy score = 48.499
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=48.499
# Iter 01: open/close 0->13 → 49.137
# Iter 02: open/close 8->14 → 49.461
# Iter 03: open/close 17->19 → 50.671
# Iter 04: open/close 19->7 → 50.695
# Iter 05: open/close 4->5 → 50.923
# Iter 06: open/close 5->12 → 53.810
# Iter 07: open/close 7->19 → 55.343
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 22.
# ✅ Final objective (closest_only) = 55.343
#      LS score = 55.343 (t=0.86s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=55.343
# ✅ Final SA objective (closest_only) = 55.343
#      SA score = 55.343 (t=0.25s)
#
# 📌 N=20 | Policy=closest_priority | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 59.992 (t=0.04s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (closest_priority).
#      Greedy score = 31.949
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=31.949
# Iter 01: open/close 3->10 → 40.449
# Iter 02: open/close 10->14 → 40.529
# Iter 03: open/close 9->13 → 44.414
# Iter 04: open/close 8->12 → 48.470
# Iter 05: open/close 12->7 → 48.856
# Iter 06: open/close 16->11 → 48.940
# Iter 07: open/close 7->17 → 52.475
# Iter 08: open/close 17->12 → 53.799
# Iter 09: open/close 11->8 → 53.799
# Iter 10: open/close 8->19 → 55.328
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 25.
# ✅ Final objective (closest_priority) = 55.328
#      LS score = 55.328 (t=1.01s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=55.328
# ✅ Final SA objective (closest_priority) = 55.328
#      SA score = 55.328 (t=0.31s)
#
# 📌 N=20 | Policy=system_optimum | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 57.472 (t=0.10s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (system_optimum).
#      Greedy score = 31.046
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=31.046
# Iter 01: open/close 8->10 → 35.553
# Iter 02: open/close 3->11 → 39.062
# Iter 03: open/close 11->2 → 39.705
# Iter 04: open/close 9->8 → 41.383
# Iter 05: open/close 8->12 → 42.977
# Iter 06: open/close 12->0 → 44.044
# Iter 07: open/close 10->13 → 45.508
# Iter 08: open/close 16->4 → 47.100
# Iter 09: open/close 13->19 → 47.739
# Iter 10: open/close 4->1 → 50.621
# Iter 11: open/close 1->6 → 50.850
# Iter 12: open/close 6->13 → 52.294
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 27.
# ✅ Final objective (system_optimum) = 52.294
#      LS score = 52.294 (t=1.01s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=52.294
# ✅ Final SA objective (system_optimum) = 52.294
#      SA score = 52.294 (t=0.29s)
#
# 📌 N=20 | Policy=uniform | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 17.515 (t=0.02s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (uniform).
#      Greedy score = 13.733
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=13.733
# Iter 01: open/close 13->10 → 14.183
# Iter 02: open/close 8->16 → 14.386
# Iter 03: open/close 16->6 → 15.417
# Iter 04: open/close 6->7 → 15.945
# Iter 05: open/close 11->4 → 17.510
# Iter 06: open/close 4->0 → 17.515
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 21.
# ✅ Final objective (uniform) = 17.515
#      LS score = 17.515 (t=1.13s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=17.515
# ✅ Final SA objective (uniform) = 17.515
#      SA score = 17.515 (t=0.27s)
#
# 📌 N=40 | Policy=closest_only | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 110.612 (t=4.59s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (closest_only).
#      Greedy score = 96.642
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=96.642
# Iter 01: open/close 31->38 → 103.615
# Iter 02: open/close 38->5 → 105.149
# Iter 03: open/close 39->16 → 105.985
# Iter 04: open/close 5->7 → 107.516
# Iter 05: open/close 15->14 → 108.809
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 20.
# ✅ Final objective (closest_only) = 108.809
#      LS score = 108.809 (t=8.21s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=108.809
# Iter 175: SA improved → 110.781 (T=0.6634)
# ✅ Final SA objective (closest_only) = 110.781
#      SA score = 110.781 (t=1.00s)
#
# 📌 N=40 | Policy=closest_priority | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 112.274 (t=0.14s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (closest_priority).
#      Greedy score = 36.238
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=36.238
# Iter 01: open/close 24->2 → 59.433
# Iter 02: open/close 1->25 → 64.022
# Iter 03: open/close 2->22 → 64.781
# Iter 04: open/close 29->18 → 74.409
# Iter 05: open/close 3->31 → 80.915
# Iter 06: open/close 25->6 → 85.562
# Iter 07: open/close 18->26 → 88.936
# Iter 08: open/close 22->38 → 92.876
# Iter 09: open/close 35->37 → 99.736
# Iter 10: open/close 37->22 → 99.738
# Iter 11: open/close 38->32 → 102.016
# Iter 12: open/close 26->8 → 102.016
# Iter 13: open/close 8->15 → 102.016
# Iter 14: open/close 31->36 → 105.123
# Iter 15: open/close 15->30 → 105.123
# Iter 16: open/close 6->10 → 106.938
# Iter 17: open/close 36->9 → 106.939
# Iter 18: open/close 32->11 → 106.942
# Iter 19: open/close 22->27 → 106.943
# Iter 20: open/close 11->13 → 108.906
# Iter 21: open/close 10->0 → 108.911
# Iter 22: open/close 9->39 → 108.911
# Iter 23: open/close 39->17 → 108.912
# Iter 24: open/close 0->34 → 108.912
# Iter 25: open/close 27->2 → 108.915
# ↪️ Switching to next neighborhood: MERGE
# ✅ Final objective (closest_priority) = 108.915
#      LS score = 108.915 (t=7.93s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=108.915
# ✅ Final SA objective (closest_priority) = 108.915
#      SA score = 108.915 (t=1.11s)
#
# 📌 N=40 | Policy=system_optimum | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 106.101 (t=0.12s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (system_optimum).
#      Greedy score = 34.430
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=34.430
# Iter 01: open/close 29->7 → 56.177
# Iter 02: open/close 35->31 → 74.116
# Iter 03: open/close 24->0 → 88.391
# Iter 04: open/close 1->30 → 88.482
# Iter 05: open/close 31->4 → 88.744
# Iter 06: open/close 3->1 → 93.111
# Iter 07: open/close 0->27 → 95.213
# Iter 08: open/close 1->23 → 99.017
# Iter 09: open/close 4->34 → 100.042
# Iter 10: open/close 27->28 → 100.179
# Iter 11: open/close 34->0 → 103.187
# Iter 12: open/close 23->13 → 103.235
# Iter 13: open/close 7->38 → 103.377
# Iter 14: open/close 13->23 → 103.398
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 29.
# ✅ Final objective (system_optimum) = 103.398
#      LS score = 103.398 (t=11.13s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=103.398
# ✅ Final SA objective (system_optimum) = 103.398
#      SA score = 103.398 (t=0.98s)
#
# 📌 N=40 | Policy=uniform | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 19.322 (t=0.04s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (uniform).
#      Greedy score = 16.582
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=16.582
# Iter 01: open/close 1->26 → 17.426
# Iter 02: open/close 0->10 → 17.743
# Iter 03: open/close 34->27 → 17.984
# Iter 04: open/close 26->38 → 18.010
# Iter 05: open/close 38->20 → 18.023
# Iter 06: open/close 20->34 → 18.572
# Iter 07: open/close 2->25 → 19.120
# Iter 08: open/close 25->4 → 19.234
# Iter 09: open/close 4->0 → 19.322
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 24.
# ✅ Final objective (uniform) = 19.322
#      LS score = 19.322 (t=11.88s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=19.322
# ✅ Final SA objective (uniform) = 19.322
#      SA score = 19.322 (t=0.88s)
#
# 📌 N=60 | Policy=closest_only | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
# WARNING: Loading a feasible but suboptimal solution. Please set
# load_solution=False and check results.termination_condition and
# results.found_feasible_solution() before loading a solution.
#     ⚠️ Exact SUBOPTIMAL: 179.389 (t=120.20s, term=TerminationCondition.maxTimeLimit)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 6 stations (closest_only).
#      Greedy score = 126.696
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=126.696
# Iter 01: open/close 32->43 → 145.375
# Iter 02: open/close 47->9 → 146.984
# Iter 03: open/close 9->16 → 155.712
# Iter 04: open/close 3->50 → 167.665
# Iter 05: open/close 50->32 → 170.934
# Iter 06: open/close 51->25 → 171.777
# Iter 07: open/close 45->5 → 171.945
# Iter 08: open/close 25->51 → 172.474
# Iter 09: open/close 51->47 → 172.949
# Iter 10: open/close 47->6 → 173.541
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 25.
# ✅ Final objective (closest_only) = 173.541
#      LS score = 173.541 (t=34.95s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=173.541
# ✅ Final SA objective (closest_only) = 173.541
#      SA score = 173.541 (t=1.89s)
#
# 📌 N=60 | Policy=closest_priority | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 179.971 (t=0.10s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 6 stations (closest_priority).
#      Greedy score = 85.167
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=85.167
# Iter 01: open/close 55->17 → 97.328
# Iter 02: open/close 17->39 → 101.345
# Iter 03: open/close 36->13 → 131.009
# Iter 04: open/close 13->29 → 131.276
# Iter 05: open/close 44->59 → 139.393
# Iter 06: open/close 39->0 → 155.166
# Iter 07: open/close 31->49 → 156.482
# Iter 08: open/close 24->53 → 168.069
# Iter 09: open/close 0->28 → 169.375
# Iter 10: open/close 28->21 → 170.719
# Iter 11: open/close 29->56 → 170.723
# Iter 12: open/close 56->10 → 170.723
# Iter 13: open/close 59->28 → 171.867
# Iter 14: open/close 49->35 → 174.315
# Iter 15: open/close 21->38 → 174.576
# Iter 16: open/close 10->51 → 175.700
# Iter 17: open/close 51->25 → 175.700
# Iter 18: open/close 35->57 → 175.702
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# ✅ Final objective (closest_priority) = 175.702
#      LS score = 175.702 (t=36.07s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=175.702
# ✅ Final SA objective (closest_priority) = 175.702
#      SA score = 175.702 (t=2.19s)
#
# 📌 N=60 | Policy=system_optimum | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 171.815 (t=2.28s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 6 stations (system_optimum).
#      Greedy score = 80.502
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=80.502
# Iter 01: open/close 31->49 → 105.489
# Iter 02: open/close 49->6 → 105.546
# Iter 03: open/close 55->2 → 123.133
# Iter 04: open/close 44->1 → 128.471
# Iter 05: open/close 1->53 → 131.539
# Iter 06: open/close 6->51 → 135.101
# Iter 07: open/close 51->1 → 135.245
# Iter 08: open/close 48->11 → 135.266
# Iter 09: open/close 1->33 → 135.659
# Iter 10: open/close 11->6 → 140.039
# Iter 11: open/close 24->22 → 151.730
# Iter 12: open/close 6->34 → 152.226
# Iter 13: open/close 34->29 → 154.482
# Iter 14: open/close 53->46 → 155.158
# Iter 15: open/close 29->58 → 155.203
# Iter 16: open/close 33->23 → 155.292
# Iter 17: open/close 58->35 → 155.892
# Iter 18: open/close 23->6 → 156.535
# Iter 19: open/close 36->55 → 159.187
# Iter 20: open/close 35->56 → 159.246
# Iter 21: open/close 55->52 → 159.424
# Iter 22: open/close 2->39 → 160.545
# Iter 23: open/close 52->27 → 161.622
# Iter 24: open/close 39->18 → 162.258
# Iter 25: open/close 46->59 → 163.006
# Iter 26: open/close 22->20 → 163.676
# Iter 27: open/close 20->40 → 163.687
# Iter 28: open/close 18->19 → 163.696
# Iter 29: open/close 59->14 → 164.367
# Iter 30: open/close 19->17 → 164.433
# ✅ Final objective (system_optimum) = 164.433
#      LS score = 164.433 (t=17.16s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=164.433
# ✅ Final SA objective (system_optimum) = 164.433
#      SA score = 164.433 (t=2.47s)
#
# 📌 N=60 | Policy=uniform | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 23.984 (t=0.13s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 6 stations (uniform).
#      Greedy score = 20.145
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=20.145
# Iter 01: open/close 20->34 → 20.199
# Iter 02: open/close 4->43 → 20.228
# Iter 03: open/close 34->50 → 20.253
# Iter 04: open/close 50->14 → 20.874
# Iter 05: open/close 13->47 → 21.047
# Iter 06: open/close 29->3 → 21.084
# Iter 07: open/close 41->30 → 21.678
# Iter 08: open/close 30->20 → 21.899
# Iter 09: open/close 28->50 → 22.467
# Iter 10: open/close 43->10 → 22.506
# Iter 11: open/close 20->34 → 22.560
# Iter 12: open/close 10->13 → 22.612
# Iter 13: open/close 3->54 → 23.642
# Iter 14: open/close 54->20 → 23.984
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 29.
# ✅ Final objective (uniform) = 23.984
#      LS score = 23.984 (t=46.91s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=23.984
# ✅ Final SA objective (uniform) = 23.984
#      SA score = 23.984 (t=1.97s)
#
# 📌 N=20 | Policy=closest_only | greedy_mode=weighted
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 60.000 (t=0.06s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 4 stations.
#      Greedy score = 40.099
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=40.099
# Iter 01: open/close 18->4 → 40.365
# Iter 02: open/close 5->8 → 48.499
# Iter 03: open/close 0->13 → 49.137
# Iter 04: open/close 8->2 → 49.461
# Iter 05: open/close 14->7 → 50.992
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 20.
# ✅ Final objective (closest_only) = 50.992
#      LS score = 50.992 (t=0.62s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=50.992
# Iter 004: SA improved → 52.545 (T=1.0000)
# Iter 005: SA improved → 54.017 (T=1.0000)
# ✅ Final SA objective (closest_only) = 54.017
#      SA score = 54.017 (t=0.23s)
#
# 📌 N=20 | Policy=closest_priority | greedy_mode=weighted
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 59.992 (t=0.04s)
#   🔹 Greedy initialization ...
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 4 stations.
#      Greedy score = 44.510
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=44.510
# Iter 01: open/close 17->6 → 47.461
# Iter 02: open/close 11->19 → 48.990
# Iter 03: open/close 19->7 → 49.079
# Iter 04: open/close 6->4 → 50.110
# Iter 05: open/close 12->14 → 50.110
# Iter 06: open/close 14->13 → 50.684
# Iter 07: open/close 7->19 → 51.730
# Iter 08: open/close 4->2 → 55.330
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 23.
# ✅ Final objective (closest_priority) = 55.330
#      LS score = 55.330 (t=0.74s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=55.330
# ✅ Final SA objective (closest_priority) = 55.330
#      SA score = 55.330 (t=0.32s)
#
# 📌 N=20 | Policy=system_optimum | greedy_mode=weighted
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 57.472 (t=0.07s)
#   🔹 Greedy initialization ...
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 4 stations.
#      Greedy score = 48.238
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=48.238
# Iter 01: open/close 7->8 → 48.354
# Iter 02: open/close 17->18 → 48.743
# Iter 03: open/close 12->5 → 48.814
# Iter 04: open/close 8->19 → 49.905
# Iter 05: open/close 6->13 → 51.349
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 20.
# ✅ Final objective (system_optimum) = 51.349
#      LS score = 51.349 (t=0.97s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=51.349
# Iter 027: SA improved → 52.072 (T=0.9500)
# Iter 041: SA improved → 52.294 (T=0.9025)
# ✅ Final SA objective (system_optimum) = 52.294
#      SA score = 52.294 (t=0.30s)
#
# 📌 N=20 | Policy=uniform | greedy_mode=weighted
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 17.515 (t=0.03s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 4 stations.
#      Greedy score = 45.062
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=13.451
# Iter 01: open/close 4->7 → 13.647
# Iter 02: open/close 7->19 → 14.096
# Iter 03: open/close 11->10 → 15.726
# Iter 04: open/close 17->4 → 16.375
# Iter 05: open/close 5->14 → 16.937
# Iter 06: open/close 10->7 → 17.068
# Iter 07: open/close 14->6 → 17.114
# Iter 08: open/close 4->0 → 17.119
# Iter 09: open/close 6->4 → 17.451
# Iter 10: open/close 0->10 → 17.510
# Iter 11: open/close 4->0 → 17.515
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 26.
# ✅ Final objective (uniform) = 17.515
#      LS score = 17.515 (t=1.35s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=17.515
# ✅ Final SA objective (uniform) = 17.515
#      SA score = 17.515 (t=0.27s)
#
# 📌 N=40 | Policy=closest_only | greedy_mode=weighted
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 110.612 (t=4.80s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 5 stations.
#      Greedy score = 89.365
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=89.365
# Iter 01: open/close 6->34 → 90.334
# Iter 02: open/close 34->10 → 94.179
# Iter 03: open/close 10->13 → 94.783
# Iter 04: open/close 15->0 → 100.128
# Iter 05: open/close 0->35 → 101.760
# Iter 06: open/close 35->33 → 107.958
# Iter 07: open/close 38->28 → 110.781
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 22.
# ✅ Final objective (closest_only) = 110.781
#      LS score = 110.781 (t=7.04s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=110.781
# ✅ Final SA objective (closest_only) = 110.781
#      SA score = 110.781 (t=0.86s)
#
# 📌 N=40 | Policy=closest_priority | greedy_mode=weighted
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 112.274 (t=0.15s)
#   🔹 Greedy initialization ...
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 5 stations.
#      Greedy score = 100.552
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=100.552
# Iter 01: open/close 4->13 → 101.961
# Iter 02: open/close 27->2 → 103.285
# Iter 03: open/close 20->34 → 103.586
# Iter 04: open/close 34->17 → 104.861
# Iter 05: open/close 13->23 → 104.862
# Iter 06: open/close 23->10 → 106.940
# Iter 07: open/close 17->4 → 106.943
# Iter 08: open/close 4->18 → 106.944
# Iter 09: open/close 18->16 → 106.944
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 24.
# ✅ Final objective (closest_priority) = 106.944
#      LS score = 106.944 (t=9.16s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=106.944
# Iter 169: SA improved → 108.915 (T=0.6634)
# Iter 195: SA improved → 108.915 (T=0.6302)
# ✅ Final SA objective (closest_priority) = 108.915
#      SA score = 108.915 (t=0.97s)
#
# 📌 N=40 | Policy=system_optimum | greedy_mode=weighted
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 106.101 (t=0.11s)
#   🔹 Greedy initialization ...
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 5 stations.
#      Greedy score = 73.925
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=73.925
# Iter 01: open/close 34->27 → 79.891
# Iter 02: open/close 26->5 → 80.540
# Iter 03: open/close 3->13 → 98.897
# Iter 04: open/close 27->36 → 99.206
# Iter 05: open/close 36->9 → 99.318
# Iter 06: open/close 5->14 → 99.562
# Iter 07: open/close 4->38 → 99.685
# Iter 08: open/close 13->32 → 100.223
# Iter 09: open/close 9->16 → 100.346
# Iter 10: open/close 32->13 → 102.806
# Iter 11: open/close 16->18 → 102.834
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 26.
# ✅ Final objective (system_optimum) = 102.834
#      LS score = 102.834 (t=7.97s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=102.834
# ✅ Final SA objective (system_optimum) = 102.834
#      SA score = 102.834 (t=0.99s)
#
# 📌 N=40 | Policy=uniform | greedy_mode=weighted
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 19.322 (t=0.04s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 5 stations.
#      Greedy score = 88.855
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=13.365
# Iter 01: open/close 22->20 → 13.417
# Iter 02: open/close 9->30 → 13.842
# Iter 03: open/close 30->18 → 14.142
# Iter 04: open/close 18->38 → 14.402
# Iter 05: open/close 36->34 → 15.623
# Iter 06: open/close 37->28 → 16.164
# Iter 07: open/close 34->27 → 16.405
# Iter 08: open/close 20->34 → 16.954
# Iter 09: open/close 38->25 → 17.303
# Iter 10: open/close 27->13 → 17.312
# Iter 11: open/close 34->27 → 17.553
# Iter 12: open/close 28->20 → 17.677
# Iter 13: open/close 13->10 → 17.733
# Iter 14: open/close 20->13 → 18.532
# Iter 15: open/close 26->32 → 18.615
# Iter 16: open/close 25->4 → 18.729
# Iter 17: open/close 32->34 → 19.234
# Iter 18: open/close 4->0 → 19.322
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# ✅ Final objective (uniform) = 19.322
#      LS score = 19.322 (t=9.25s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=19.322
# ✅ Final SA objective (uniform) = 19.322
#      SA score = 19.322 (t=1.04s)
#
# 📌 N=60 | Policy=closest_only | greedy_mode=weighted
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
# WARNING: Loading a feasible but suboptimal solution. Please set
# load_solution=False and check results.termination_condition and
# results.found_feasible_solution() before loading a solution.
#     ⚠️ Exact SUBOPTIMAL: 179.389 (t=120.21s, term=TerminationCondition.maxTimeLimit)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 6 stations.
#      Greedy score = 144.404
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=144.404
# Iter 01: open/close 8->55 → 152.148
# Iter 02: open/close 55->19 → 153.954
# Iter 03: open/close 19->54 → 155.087
# Iter 04: open/close 54->43 → 159.165
# Iter 05: open/close 25->34 → 162.119
# Iter 06: open/close 22->12 → 163.820
# Iter 07: open/close 47->35 → 164.348
# Iter 08: open/close 12->28 → 165.410
# Iter 09: open/close 20->26 → 165.689
# Iter 10: open/close 34->3 → 167.417
# Iter 11: open/close 35->34 → 167.909
# Iter 12: open/close 34->49 → 168.234
# Iter 13: open/close 49->38 → 169.281
# Iter 14: open/close 50->51 → 172.267
# Iter 15: open/close 38->45 → 173.187
# Iter 16: open/close 45->0 → 176.153
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# ✅ Final objective (closest_only) = 176.153
#      LS score = 176.153 (t=30.68s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=176.153
# ✅ Final SA objective (closest_only) = 176.153
#      SA score = 176.153 (t=2.24s)
#
# 📌 N=60 | Policy=closest_priority | greedy_mode=weighted
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 179.971 (t=0.13s)
#   🔹 Greedy initialization ...
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 6 stations.
#      Greedy score = 152.505
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=152.505
# Iter 01: open/close 10->43 → 156.438
# Iter 02: open/close 36->0 → 161.752
# Iter 03: open/close 48->42 → 163.138
# Iter 04: open/close 23->47 → 163.143
# Iter 05: open/close 0->55 → 165.083
# Iter 06: open/close 47->6 → 167.067
# Iter 07: open/close 46->11 → 167.682
# Iter 08: open/close 55->31 → 167.684
# Iter 09: open/close 31->21 → 171.718
# Iter 10: open/close 43->54 → 173.770
# Iter 11: open/close 6->47 → 173.771
# Iter 12: open/close 54->18 → 173.774
# Iter 13: open/close 47->10 → 173.775
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 28.
# ✅ Final objective (closest_priority) = 173.775
#      LS score = 173.775 (t=42.67s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=173.775
# ✅ Final SA objective (closest_priority) = 173.775
#      SA score = 173.775 (t=2.30s)
#
# 📌 N=60 | Policy=system_optimum | greedy_mode=weighted
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 171.815 (t=2.08s)
#   🔹 Greedy initialization ...
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 6 stations.
#      Greedy score = 150.933
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=150.933
# Iter 01: open/close 7->59 → 154.585
# Iter 02: open/close 5->28 → 156.391
# Iter 03: open/close 59->0 → 157.540
# Iter 04: open/close 20->58 → 160.408
# Iter 05: open/close 0->45 → 160.852
# Iter 06: open/close 25->51 → 162.007
# Iter 07: open/close 51->10 → 162.141
# Iter 08: open/close 58->35 → 162.321
# Iter 09: open/close 42->20 → 163.351
# Iter 10: open/close 45->59 → 163.438
# Iter 11: open/close 20->40 → 164.742
# Iter 12: open/close 35->29 → 164.808
# Iter 13: open/close 29->56 → 165.203
# Iter 14: open/close 10->49 → 165.702
# Iter 15: open/close 49->6 → 165.795
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 30.
# ✅ Final objective (system_optimum) = 165.795
#      LS score = 165.795 (t=47.95s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=165.795
# ✅ Final SA objective (system_optimum) = 165.795
#      SA score = 165.795 (t=2.58s)
#
# 📌 N=60 | Policy=uniform | greedy_mode=weighted
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 23.984 (t=0.11s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using WEIGHTED greedy (W1)
# ✅ Weighted greedy (W1) initialized with 6 stations.
#      Greedy score = 146.527
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=19.811
# Iter 01: open/close 52->37 → 20.537
# Iter 02: open/close 51->41 → 20.581
# Iter 03: open/close 7->13 → 20.692
# Iter 04: open/close 32->54 → 20.768
# Iter 05: open/close 13->50 → 20.852
# Iter 06: open/close 50->47 → 20.941
# Iter 07: open/close 54->4 → 21.156
# Iter 08: open/close 34->14 → 21.802
# Iter 09: open/close 11->20 → 22.547
# Iter 10: open/close 20->50 → 22.625
# Iter 11: open/close 4->34 → 22.805
# Iter 12: open/close 37->12 → 23.047
# Iter 13: open/close 41->43 → 23.765
# Iter 14: open/close 43->10 → 23.805
# Iter 15: open/close 10->20 → 23.862
# Iter 16: open/close 12->7 → 23.872
# Iter 17: open/close 7->13 → 23.984
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# ✅ Final objective (uniform) = 23.984
#      LS score = 23.984 (t=50.13s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=23.984
# ✅ Final SA objective (uniform) = 23.984
#      SA score = 23.984 (t=2.01s)
# ✅ Saved two tables to results/two_tables_summary.xlsx
#     ID                              Exact                           Heuristic  \
#      N seed            policy Score exact    Time (s)    Gap (%) Greedy score
# 0   20    1      closest_only   60.000000    0.066354   9.971194    52.177969
# 1   20    1  closest_priority   59.991538    0.040744   9.976297    52.170046
# 2   20    1    system_optimum   57.471534    0.051227  10.652534    49.885673
# 3   20    1           uniform   17.515237    0.023526   0.000000    17.515237
# 4   40    1      closest_only  110.611676    4.596023   1.030031   105.371702
# 5   40    1  closest_priority  112.274105    0.119700   6.167122   105.350024
# 6   40    1    system_optimum  106.100835    0.123567   4.636979   101.180962
# 7   40    1           uniform   19.322332    0.049802   0.000000    19.322332
# 8   60    1      closest_only  179.388645  120.202734   1.144893   168.521426
# 9   60    1  closest_priority  179.971064    0.114191   1.715610   166.441207
# 10  60    1    system_optimum  171.815212    2.015215   2.932643   159.929734
# 11  60    1           uniform   23.983676    0.075866   0.000000    23.983676
#
#
#       LS score LS time (s)    SA score SA time (s)
# 0    54.017284    0.622692   55.343494    0.229407
# 1    54.006604    0.707092   55.330003    0.242327
# 2    51.349360    0.851559   51.349360    0.299402
# 3    17.515237    1.001320   17.515237    0.274240
# 4   109.472342    8.514918  109.472342    1.000844
# 5   105.350024    8.635857  109.444113    1.182322
# 6   101.180962    8.386692  102.843120    1.153376
# 7    19.322332   10.963775   19.322332    1.097245
# 8   177.334837   36.873528  177.334837    2.040852
# 9   176.883463   45.911198  176.883463    2.178654
# 10  166.776484   36.100121  166.776484    2.197980
# 11   23.983676   38.790953   23.983676    2.283999
#      N  seed            policy  score_exact  time_exact  det_greedy  \
# 0   20     1      closest_only    60.000000    0.066354   52.177969
# 1   20     1  closest_priority    59.991538    0.040744   52.170046
# 2   20     1    system_optimum    57.471534    0.051227   49.885673
# 3   20     1           uniform    17.515237    0.023526   17.515237
# 4   40     1      closest_only   110.611676    4.596023  105.371702
# 5   40     1  closest_priority   112.274105    0.119700  105.350024
# 6   40     1    system_optimum   106.100835    0.123567  101.180962
# 7   40     1           uniform    19.322332    0.049802   19.322332
# 8   60     1      closest_only   179.388645  120.202734  168.521426
# 9   60     1  closest_priority   179.971064    0.114191  166.441207
# 10  60     1    system_optimum   171.815212    2.015215  159.929734
# 11  60     1           uniform    23.983676    0.075866   23.983676
#
#         det_LS  det_LS_time  random_greedy   random_LS  random_LS_time  \
# 0    54.017284     0.622692      48.498638   55.343494        0.864198
# 1    54.006604     0.707092      31.948597   55.327781        1.012300
# 2    51.349360     0.851559      31.046020   52.294424        1.007797
# 3    17.515237     1.001320      13.733325   17.515237        1.125628
# 4   109.472342     8.514918      96.642093  108.808503        8.210288
# 5   105.350024     8.635857      36.237935  108.914544        7.928292
# 6   101.180962     8.386692      34.429814  103.397855       11.131215
# 7    19.322332    10.963775      16.581530   19.322332       11.881527
# 8   177.334837    36.873528     126.696077  173.540714       34.951157
# 9   176.883463    45.911198      85.167426  175.701553       36.066013
# 10  166.776484    36.100121      80.501813  164.433269       17.163513
# 11   23.983676    38.790953      20.145178   23.983676       46.914984
#
#     weighted_greedy  weighted_LS  weighted_LS_time  Det vs Exact (%)  \
# 0         40.098565    50.991637          0.623877         -9.971194
# 1         44.510433    55.330003          0.737301         -9.976297
# 2         48.237506    51.349360          0.973209        -10.652534
# 3         45.062182    17.515237          1.351915          0.000000
# 4         89.365344   110.611676          7.044159         -1.030031
# 5        100.552179   106.944287          9.161608         -6.167122
# 6         73.924843   102.833799          7.968962         -4.636979
# 7         88.855491    19.322332          9.246369          0.000000
# 8        144.404069   176.153271         30.675957         -1.144893
# 9        152.504928   173.774736         42.665536         -1.715610
# 10       150.933237   165.794571         47.953468         -2.932643
# 11       146.526725    23.983676         50.130733          0.000000
#
#     Random vs Exact (%)  Weighted vs Exact (%)  (Weighted-Det) / Exact (%)  \
# 0             -7.760843             -15.013939                   -5.042745
# 1             -7.774025              -7.770321                    2.205976
# 2             -9.008130             -10.652534                    0.000000
# 3              0.000000               0.000000                    0.000000
# 4             -1.630183               0.000000                    1.030031
# 5             -2.992285              -4.747148                    1.419974
# 6             -2.547558              -3.079180                    1.557798
# 7              0.000000               0.000000                    0.000000
# 8             -3.259923              -1.803556                   -0.658663
# 9             -2.372332              -3.442958                   -1.727348
# 10            -4.296443              -3.504137                   -0.571494
# 11             0.000000               0.000000                    0.000000
#
#     (Weighted-Rand) / Exact (%)
# 0                     -7.253096
# 1                      0.003705
# 2                     -1.644404
# 3                      0.000000
# 4                      1.630183
# 5                     -1.754863
# 6                     -0.531622
# 7                      0.000000
# 8                      1.456367
# 9                     -1.070626
# 10                     0.792306
# 11                     0.000000
