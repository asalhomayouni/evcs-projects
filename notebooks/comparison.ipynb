# %%
# === Notebook Setup Cell ===
import sys, os

# Add project root (evcs-projects/)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# Add scripts folder
scripts_path = os.path.abspath(os.path.join(project_root, "scripts"))
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

print("Python path configured. Last entries:")
print(sys.path[-2:])

# import comparison helper functions (must exist in comparisonscript.py)
from comparisonscript import run_batch_one_pass
# Out:
# Python path configured. Last entries:
# ['c:\\Users\\asus\\OneDrive\\EV-projects\\evcs-projects', 'c:\\Users\\asus\\OneDrive\\EV-projects\\evcs-projects\\scripts']

# %%
# === Two-table export cell (fixed) ===

import pandas as pd
import numpy as np
from pathlib import Path
from scripts.comparisonscript import run_batch_one_pass   # <— correct import

# 1) Deterministic pass
df_det = run_batch_one_pass(
    Ns=(20,40),
    seeds=(1,),
    policies=("closest_only", "closest_priority", "system_optimum", "uniform"),
    greedy_mode="deterministic",
    max_iter=30,
)

# Build pretty MultiIndex table
df_main = df_det.copy()
df_main.columns = pd.MultiIndex.from_tuples([
    ("ID",        "N"),
    ("ID",        "seed"),
    ("ID",        "policy"),
    ("Exact",     "Score exact"),
    ("Exact",     "Time (s)"),
    ("Exact",     "Gap (%)"),
    ("Heuristic", "Greedy score"),
    ("Heuristic", "LS score"),
    ("Heuristic", "LS time (s)"),
    ("Heuristic", "SA score"),
    ("Heuristic", "SA time (s)"),
])

# 2) Random pass
df_rand = run_batch_one_pass(
    Ns=(20,40),
    seeds=(1,),
    policies=("closest_only", "closest_priority", "system_optimum", "uniform"),
    greedy_mode="random",
    max_iter=30,
)

# Comparison table
df_rand_cmp = df_rand.rename(columns={
    "score_greedy": "random_greedy",
    "score_LS":     "random_LS",
    "time_LS":      "random_LS_time",
})
df_det_cmp = df_det.rename(columns={
    "score_greedy": "det_greedy",
    "score_LS":     "det_LS",
    "time_LS":      "det_LS_time",
})

df_rand_cmp = df_rand_cmp[["N","seed","policy","random_greedy","random_LS","random_LS_time"]]
df_det_cmp  = df_det_cmp [["N","seed","policy","score_exact","time_exact","det_greedy","det_LS","det_LS_time"]]

df_compare = pd.merge(df_det_cmp, df_rand_cmp, on=["N","seed","policy"], how="inner")

df_compare = df_compare[[
    "N","seed","policy",
    "score_exact","time_exact",
    "det_greedy","det_LS","det_LS_time",
    "random_greedy","random_LS","random_LS_time",
]]

# 3) Export BOTH tables into ONE Excel workbook
Path("results").mkdir(exist_ok=True)
out_xlsx = "results/two_tables_summary.xlsx"

with pd.ExcelWriter(out_xlsx, engine="xlsxwriter") as writer:
    df_main.to_excel(writer, sheet_name="Main (deterministic)", index=True)   # <-- MUST be True
    df_compare.to_excel(writer, sheet_name="Random vs Deterministic", index=False)

print(f"✅ Saved two tables to {out_xlsx}")

# 4) Show tables
display(df_main.head())
display(df_compare.head())
# Out:
# 📌 N=20 | Policy=closest_only | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 60.000 (t=0.08s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 52.178
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=52.178
# Iter 01: open/close 10->13 → 54.017
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 16.
# ✅ Final objective (closest_only) = 54.017
#      LS score = 54.017 (t=0.71s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=54.017
# Iter 110: SA improved → 55.343 (T=0.7738)
# ✅ Final SA objective (closest_only) = 55.343
#      SA score = 55.343 (t=0.23s)
#
# 📌 N=20 | Policy=closest_priority | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 59.992 (t=0.04s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 52.170
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=52.170
# Iter 01: open/close 10->6 → 52.170
# Iter 02: open/close 6->13 → 54.007
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 17.
# ✅ Final objective (closest_priority) = 54.007
#      LS score = 54.007 (t=0.90s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=54.007
# Iter 014: SA improved → 55.328 (T=1.0000)
# ✅ Final SA objective (closest_priority) = 55.328
#      SA score = 55.328 (t=0.32s)
#
# 📌 N=20 | Policy=system_optimum | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 57.472 (t=0.05s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 49.886
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=49.886
# Iter 01: open/close 10->6 → 49.905
# Iter 02: open/close 6->13 → 51.349
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 17.
# ✅ Final objective (system_optimum) = 51.349
#      LS score = 51.349 (t=0.81s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=51.349
# Iter 037: SA improved → 52.072 (T=0.9500)
# ✅ Final SA objective (system_optimum) = 52.072
#      SA score = 52.072 (t=0.27s)
#
# 📌 N=20 | Policy=uniform | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 17.515 (t=0.02s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 17.515
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=17.515
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (uniform) = 17.515
#      LS score = 17.515 (t=0.88s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=17.515
# ✅ Final SA objective (uniform) = 17.515
#      SA score = 17.515 (t=0.25s)
#
# 📌 N=40 | Policy=closest_only | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 110.612 (t=4.09s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 105.372
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=105.372
# Iter 01: open/close 19->14 → 106.967
# Iter 02: open/close 7->38 → 109.472
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 17.
# ✅ Final objective (closest_only) = 109.472
#      LS score = 109.472 (t=7.00s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=109.472
# ✅ Final SA objective (closest_only) = 109.472
#      SA score = 109.472 (t=0.90s)
#
# 📌 N=40 | Policy=closest_priority | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 112.274 (t=0.12s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 105.350
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=105.350
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (closest_priority) = 105.350
#      LS score = 105.350 (t=7.56s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=105.350
# Iter 072: SA improved → 107.573 (T=0.8574)
# ✅ Final SA objective (closest_priority) = 107.573
#      SA score = 107.573 (t=1.05s)
#
# 📌 N=40 | Policy=system_optimum | greedy_mode=deterministic
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 106.101 (t=0.11s)
#   🔹 Greedy initialization ...
#      → Using SMART deterministic greedy
#      Greedy score = 101.181
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=101.181
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (system_optimum) = 101.181
#      LS score = 101.181 (t=7.62s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=101.181
# Iter 153: SA improved → 102.189 (T=0.6983)
# Iter 160: SA improved → 102.279 (T=0.6983)
# ✅ Final SA objective (system_optimum) = 102.279
#      SA score = 102.279 (t=1.04s)
#
# 📌 N=40 | Policy=uniform | greedy_mode=deterministic
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 19.322 (t=0.05s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using SMART deterministic greedy
#      Greedy score = 19.322
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=19.322
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 15.
# ✅ Final objective (uniform) = 19.322
#      LS score = 19.322 (t=9.94s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=19.322
# ✅ Final SA objective (uniform) = 19.322
#      SA score = 19.322 (t=0.93s)
#
# 📌 N=20 | Policy=closest_only | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 60.000 (t=0.06s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (closest_only).
#      Greedy score = 41.720
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=41.720
# Iter 01: open/close 1->3 → 43.761
# Iter 02: open/close 14->2 → 43.907
# Iter 03: open/close 17->11 → 44.991
# Iter 04: open/close 2->18 → 48.029
# Iter 05: open/close 11->19 → 49.562
# Iter 06: open/close 3->12 → 52.178
# Iter 07: open/close 18->14 → 53.504
# Iter 08: open/close 10->13 → 55.343
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 23.
# ✅ Final objective (closest_only) = 55.343
#      LS score = 55.343 (t=0.72s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=55.343
# ✅ Final SA objective (closest_only) = 55.343
#      SA score = 55.343 (t=0.22s)
#
# 📌 N=20 | Policy=closest_priority | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 59.992 (t=0.04s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (closest_priority).
#      Greedy score = 31.949
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=31.949
# Iter 01: open/close 8->18 → 36.144
# Iter 02: open/close 9->17 → 40.024
# Iter 03: open/close 3->1 → 44.960
# Iter 04: open/close 18->4 → 45.965
# Iter 05: open/close 17->7 → 46.101
# Iter 06: open/close 4->17 → 46.191
# Iter 07: open/close 16->15 → 49.075
# Iter 08: open/close 15->14 → 50.635
# Iter 09: open/close 7->11 → 50.636
# Iter 10: open/close 17->18 → 50.638
# Iter 11: open/close 14->12 → 50.638
# Iter 12: open/close 12->5 → 50.639
# Iter 13: open/close 1->10 → 50.641
# Iter 14: open/close 11->8 → 50.641
# Iter 15: open/close 10->13 → 52.478
# Iter 16: open/close 8->19 → 54.007
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# ✅ Final objective (closest_priority) = 54.007
#      LS score = 54.007 (t=0.88s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=54.007
# ✅ Final SA objective (closest_priority) = 54.007
#      SA score = 54.007 (t=0.26s)
#
# 📌 N=20 | Policy=system_optimum | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 57.472 (t=0.06s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (system_optimum).
#      Greedy score = 31.046
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=31.046
# Iter 01: open/close 8->12 → 35.417
# Iter 02: open/close 12->10 → 35.553
# Iter 03: open/close 3->18 → 42.441
# Iter 04: open/close 16->7 → 49.355
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 19.
# ✅ Final objective (system_optimum) = 49.355
#      LS score = 49.355 (t=0.79s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=49.355
# Iter 021: SA improved → 49.815 (T=0.9500)
# Iter 030: SA improved → 50.399 (T=0.9500)
# Iter 031: SA improved → 50.627 (T=0.9500)
# ✅ Final SA objective (system_optimum) = 50.627
#      SA score = 50.627 (t=0.27s)
#
# 📌 N=20 | Policy=uniform | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 17.515 (t=0.02s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 4 stations (uniform).
#      Greedy score = 13.670
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=13.670
# Iter 01: open/close 1->7 → 15.039
# Iter 02: open/close 14->4 → 15.417
# Iter 03: open/close 9->13 → 16.420
# Iter 04: open/close 7->19 → 16.870
# Iter 05: open/close 4->10 → 16.934
# Iter 06: open/close 0->7 → 17.125
# Iter 07: open/close 13->0 → 17.515
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 22.
# ✅ Final objective (uniform) = 17.515
#      LS score = 17.515 (t=0.99s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=17.515
# ✅ Final SA objective (uniform) = 17.515
#      SA score = 17.515 (t=0.26s)
#
# 📌 N=40 | Policy=closest_only | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'closest_only' constraints.
#     ✅ Exact OPTIMAL: 110.612 (t=4.08s)
#   🔹 Greedy initialization ...
# → Added 'closest_only' constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (closest_only).
#      Greedy score = 85.122
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_only), initial obj=85.122
# Iter 01: open/close 4->9 → 85.605
# Iter 02: open/close 25->4 → 90.647
# Iter 03: open/close 9->5 → 92.562
# Iter 04: open/close 13->8 → 96.832
# Iter 05: open/close 8->22 → 99.535
# Iter 06: open/close 22->27 → 99.675
# Iter 07: open/close 3->20 → 102.688
# Iter 08: open/close 1->13 → 105.372
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 23.
# ✅ Final objective (closest_only) = 105.372
#      LS score = 105.372 (t=7.37s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_only) | initial obj=105.372
# Iter 026: SA improved → 105.587 (T=0.9500)
# ✅ Final SA objective (closest_only) = 105.587
#      SA score = 105.587 (t=0.94s)
#
# 📌 N=40 | Policy=closest_priority | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 112.274 (t=0.12s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (closest_priority).
#      Greedy score = 36.238
#   🔹 Local Search ...
#
# 🔵 Local Search start (closest_priority), initial obj=36.238
# Iter 01: open/close 24->19 → 59.857
# Iter 02: open/close 3->32 → 69.338
# Iter 03: open/close 35->28 → 78.647
# Iter 04: open/close 1->23 → 85.771
# Iter 05: open/close 23->25 → 101.155
# Iter 06: open/close 28->18 → 101.155
# Iter 07: open/close 29->1 → 101.158
# Iter 08: open/close 32->38 → 101.160
# Iter 09: open/close 18->17 → 101.713
# Iter 10: open/close 38->4 → 103.978
# Iter 11: open/close 1->10 → 107.568
# Iter 12: open/close 4->18 → 107.569
# Iter 13: open/close 19->5 → 107.572
# Iter 14: open/close 5->12 → 109.002
# Iter 15: open/close 12->14 → 110.292
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 30.
# ✅ Final objective (closest_priority) = 110.292
#      LS score = 110.292 (t=9.25s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (closest_priority) | initial obj=110.292
# ✅ Final SA objective (closest_priority) = 110.292
#      SA score = 110.292 (t=1.07s)
#
# 📌 N=40 | Policy=system_optimum | greedy_mode=random
#   🔹 Exact solve ...
#     ✅ Exact OPTIMAL: 106.101 (t=0.11s)
#   🔹 Greedy initialization ...
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (system_optimum).
#      Greedy score = 34.430
#   🔹 Local Search ...
#
# 🔵 Local Search start (system_optimum), initial obj=34.430
# Iter 01: open/close 29->18 → 55.922
# Iter 02: open/close 35->26 → 73.313
# Iter 03: open/close 1->20 → 77.186
# Iter 04: open/close 18->28 → 77.791
# Iter 05: open/close 26->22 → 82.276
# Iter 06: open/close 22->27 → 84.361
# Iter 07: open/close 27->5 → 84.926
# Iter 08: open/close 20->32 → 91.345
# Iter 09: open/close 5->14 → 93.410
# Iter 10: open/close 32->27 → 93.508
# Iter 11: open/close 27->38 → 96.311
# Iter 12: open/close 38->7 → 97.024
# Iter 13: open/close 24->13 → 100.472
# Iter 14: open/close 14->12 → 100.561
# Iter 15: open/close 7->38 → 102.092
# Iter 16: open/close 3->25 → 102.316
# Iter 17: open/close 38->17 → 102.374
# Iter 18: open/close 25->6 → 104.309
# Iter 19: open/close 6->33 → 104.545
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# ✅ Final objective (system_optimum) = 104.545
#      LS score = 104.545 (t=7.41s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (system_optimum) | initial obj=104.545
# ✅ Final SA objective (system_optimum) = 104.545
#      SA score = 104.545 (t=1.11s)
#
# 📌 N=40 | Policy=uniform | greedy_mode=random
#   🔹 Exact solve ...
# → Added 'uniform' equal-split constraints.
#     ✅ Exact OPTIMAL: 19.322 (t=0.06s)
#   🔹 Greedy initialization ...
# → Added 'uniform' equal-split constraints.
#      → Using RANDOM greedy
# ✅ Greedy initialized with 5 stations (uniform).
#      Greedy score = 14.866
#   🔹 Local Search ...
#
# 🔵 Local Search start (uniform), initial obj=14.866
# Iter 01: open/close 26->20 → 14.906
# Iter 02: open/close 34->13 → 15.156
# Iter 03: open/close 33->26 → 15.515
# Iter 04: open/close 13->10 → 15.571
# Iter 05: open/close 7->34 → 15.859
# Iter 06: open/close 34->27 → 16.100
# Iter 07: open/close 29->5 → 17.341
# Iter 08: open/close 26->25 → 17.716
# Iter 09: open/close 20->7 → 17.977
# Iter 10: open/close 5->0 → 18.571
# Iter 11: open/close 27->13 → 18.580
# Iter 12: open/close 0->27 → 18.832
# Iter 13: open/close 25->0 → 19.034
# Iter 14: open/close 0->34 → 19.046
# Iter 15: open/close 7->0 → 19.322
# ↪️ Switching to next neighborhood: MERGE
# ↪️ Switching to next neighborhood: SHIFT
# 🔚 No improvement in any neighborhood. Stopping at iter 30.
# ✅ Final objective (uniform) = 19.322
#      LS score = 19.322 (t=13.55s)
#   🔹 Simulated Annealing ...
#
# 🔥 Simulated Annealing start (uniform) | initial obj=19.322
# ✅ Final SA objective (uniform) = 19.322
#      SA score = 19.322 (t=0.95s)
# ✅ Saved two tables to results/two_tables_summary.xlsx
#    ID                              Exact                         Heuristic  \
#     N seed            policy Score exact  Time (s)    Gap (%) Greedy score
# 0  20    1      closest_only   60.000000  0.081832   9.971194    52.177969
# 1  20    1  closest_priority   59.991538  0.041235   9.976297    52.170046
# 2  20    1    system_optimum   57.471534  0.053163  10.652534    49.885673
# 3  20    1           uniform   17.515237  0.024208   0.000000    17.515237
# 4  40    1      closest_only  110.611676  4.086997   1.030031   105.371702
#
#
#      LS score LS time (s)    SA score SA time (s)
# 0   54.017284    0.708382   55.343494    0.234224
# 1   54.006604    0.899102   55.327781    0.322458
# 2   51.349360    0.809092   52.072178    0.265418
# 3   17.515237    0.884033   17.515237    0.246029
# 4  109.472342    6.998109  109.472342    0.902500
#     N  seed            policy  score_exact  time_exact  det_greedy  \
# 0  20     1      closest_only    60.000000    0.081832   52.177969
# 1  20     1  closest_priority    59.991538    0.041235   52.170046
# 2  20     1    system_optimum    57.471534    0.053163   49.885673
# 3  20     1           uniform    17.515237    0.024208   17.515237
# 4  40     1      closest_only   110.611676    4.086997  105.371702
#
#        det_LS  det_LS_time  random_greedy   random_LS  random_LS_time
# 0   54.017284     0.708382      41.720293   55.343494        0.724743
# 1   54.006604     0.899102      31.948597   54.006604        0.881911
# 2   51.349360     0.809092      31.046020   49.354548        0.791183
# 3   17.515237     0.884033      13.669511   17.515237        0.993369
# 4  109.472342     6.998109      85.122092  105.371702        7.366435
